# %% [markdown]
# # A first calculation: water
#
# Closed-shell water across the four built-in functionals: build the energy functional once per functional, solve with DIIS SCF.

# %%
import jax; jax.config.update("jax_enable_x64", True)
from dftax import KS, Molecule, scf
from dftax.energy.xc import LDA, PBE, PBE0, B3LYP

water = Molecule.from_xyz("O 0 0 0; H 0.7586 0 0.5043; H 0.7586 0 -0.5043", "sto-3g")
for xc in (LDA(), PBE(), PBE0(), B3LYP()):
    res = scf(KS(water, xc))
    print(f"{xc.name:6s}  E = {res.e_tot:.8f} Ha   converged={res.converged}")
# Out:
# LDA     E = -74.65256103 Ha   converged=True
# PBE     E = -75.14676588 Ha   converged=True
# PBE0    E = -75.16666412 Ha   converged=True
# B3LYP   E = -75.23213473 Ha   converged=True
